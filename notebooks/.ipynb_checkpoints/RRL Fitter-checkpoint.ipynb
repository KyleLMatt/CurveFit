# %%
import os
import sys
sys.path.append(os.getcwd() + "\\..\\leavitt")

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.optimize import curve_fit
from scipy.interpolate import interp1d
from dl import queryClient as qc
from astropy.table import Table, vstack
import utils
from collections import Counter
# Out:
# C:\Users\kylem\Anaconda3\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\kylem\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# C:\Users\kylem\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.IPBC74C7KURV7CB2PKT5Z5FNR3SIBV4J.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
pltdir = 'results/plots'
if not os.path.exists(pltdir):
    os.makedirs(pltdir)

# %%
os.getcwd()
# Out:
# 'D:\\msu\\RRLProject\\leavitt\\leavitt github\\notebooks'

# %%
gldrrl  = np.loadtxt(r'../samples/golden_RRab.txt',delimiter=',',dtype=str)
gldall  = np.loadtxt(r'../samples/all_gold_sample.txt',dtype=str)
gldelse = np.array(list(set(gldall) - set(gldrrl)))
varlist = Table.read(r'../samples/nsc_dr2_variables.fits.gz')['id']

# %%
import RRLfit
tmps = Table.read('../leavitt/data/layden_templates.fits',format='fits')['PH','RRA1','RRA2','RRA3','RRB1','RRB2','RRB3','RRC']
RRLfitter = RRLfit.RRLfitter(tmps,['u','g','r','i','z','Y','VR'],[1.4457, 1.4660, 1., 0.7833, 0.7467, 0.6696, 1.0507])
# Out:
# C:\Users\kylem\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
i=55
nm = gldrrl[i]
nm = '136330_168078'
pix = int(int(nm.split('_')[0])/1000)
cat = RRLfit.get_data(nm)
display(Counter(cat['filter']))
ptbl = Table.read(r'D:\msu\RRLProject\Psearch_res\pdata\{}\{}.fits'.format(pix,nm))
# Out:
# Counter({'u': 6, 'g': 62, 'r': 104, 'i': 79, 'z': 78, 'Y': 13})

# %%
RRLfitter.ampratio = np.array([1.8148,1.4660,1.0,0.7833,0.7467,0.7187,1.0507])
RRLfit.fit_plot(RRLfitter,nm,plist=ptbl['periods'][:5],verbose=False)
# Out:
# {0, 1, 2, 3, 4, 5}

# %% [markdown]
# - - -

# %%
clrs=[u'#1f77b4', u'#ff7f0e', u'#2ca02c', u'#d62728', u'#9467bd', u'#8c564b', u'#e377c2', u'#7f7f7f', u'#bcbd22', u'#17becf']

# %%
import selftemplate

# nm = '93142_19513'
i=0
nm = gldrrl[i]

pix = int(int(nm.split('_')[0])/1000)
cat = selftemplate.get_data(nm)
ptbl = Table.read(r'D:\msu\RRLProject\Psearch_res\pdata\{}\{}.fits'.format(pix,nm))
period = ptbl['periods'][0]
bands,pars2,template,chisq = selftemplate.selftemplate(cat,period,verbose=False)

nbands = len(bands)
t0 = pars2[1]
amp = pars2[2:2+nbands]
mnmag = pars2[-nbands:]
ph = (cat['mjd'] - pars2[1]) / period %1
sclmag = np.zeros(len(cat),float)
for i,b in enumerate(bands):
    ind, = np.where(cat['fltr']==b)
    sclmag[ind] = (cat['mag'][ind]-mnmag[i])/amp[i]
# Out:
# C:\Users\kylem\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: RuntimeWarning: divide by zero encountered in true_divide

# %%
sclmag[-1]=np.median(sclmag)

# %%
plt.scatter(ph,sclmag,c=cat['fltr'],s=10)
plt.plot(template['phase'],template['flux'],c='r')

# %% [markdown]
# ----

# %%
ptbl[:5]
# Out:
# <Table length=5>
#       periods              psi          inds
#       float64            float64       int64
# ------------------- ------------------ ------
#  0.6221807486335239 15028.377003027868 183192
#  1.6542749724898946  863.5251345810751  68837
# 0.38314738436959794  818.0273933061892 297542
# 0.41841372852648406   528.323418570191 272455
#  0.2947459726721732  439.5892035058912 386812

# %%
bestp0 = RRLfit.p_test(cat['mjd'],sclmag,ptbl['periods'])
print(bestp0)
# Out:
# 0.6221807486335239

# %%
bestp1 = RRLfit.checkHarmonics(cat['mjd'],sclmag,bestp0)
print(bestp1)
# Out:
# 0.6221807486335239

# %%
bestp2 = RRLfit.p_refine(cat['mjd'],sclmag,bestp1,k=5,N=1000)
print(bestp2)
# Out:
# 0.622183751636527

# %%
bands,pars2,template,chisq = selftemplate.selftemplate(cat,bestp2,verbose=False)

nbands = len(bands)
t0 = pars2[1]
amp = pars2[2:2+nbands]
mnmag = pars2[-nbands:]
ph = (cat['mjd'] - pars2[1]) / bestp2 %1
sclmag = np.zeros(len(cat),float)
for i,b in enumerate(bands):
    ind, = np.where(cat['fltr']==b)
    sclmag[ind] = (cat['mag'][ind]-mnmag[i])/amp[i]
# Out:
# C:\Users\kylem\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in true_divide
#   # This is added back by InteractiveShellApp.init_path()

# %%
plt.scatter(ph,sclmag,c=cat['fltr'],s=10)
plt.plot(template['phase'],template['flux'],c='r')
